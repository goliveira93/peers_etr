# %%
import pandas as pd
import os

print(os.getcwd())
df=pd.read_csv(os.path.join(".","data","cda_fi_BLC_2_202212.csv"),delimiter=";",encoding="ISO-8859-1")
# Out:
# c:\Users\Marcelo\programs\tools\dataset_cvm
# C:\Users\Marcelo\AppData\Local\Temp\ipykernel_92780\2818830206.py:5: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(os.path.join(".","data","cda_fi_BLC_2_202212.csv"),delimiter=";",encoding="ISO-8859-1")

# %%
df=df[["TP_FUNDO","CNPJ_FUNDO","DENOM_SOCIAL","TP_ATIVO","VL_MERC_POS_FINAL","CNPJ_FUNDO_COTA","NM_FUNDO_COTA"]]
#df.loc[df["CNPJ_FUNDO"]=="11.389.643/0001-95"]
sub_df=df.loc[df["CNPJ_FUNDO"]=="26.470.647/0001-70"]

# %%
#find fofs
sub_df["IS_FEEDER"]=sub_df["CNPJ_FUNDO_COTA"].isin(df["CNPJ_FUNDO"])
sub_df
# Out:
# C:\Users\Marcelo\AppData\Local\Temp\ipykernel_92780\2244613608.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["IS_FEEDER"]=sub_df["CNPJ_FUNDO_COTA"].isin(df["CNPJ_FUNDO"])
#       TP_FUNDO          CNPJ_FUNDO  \
# 77083       FI  26.470.647/0001-70
# 77084       FI  26.470.647/0001-70
# 77085       FI  26.470.647/0001-70
# 77086       FI  26.470.647/0001-70
# 77087       FI  26.470.647/0001-70
# 77088       FI  26.470.647/0001-70
# 77089       FI  26.470.647/0001-70
# 77090       FI  26.470.647/0001-70
# 77091       FI  26.470.647/0001-70
# 77092       FI  26.470.647/0001-70
# 77093       FI  26.470.647/0001-70
# 77094       FI  26.470.647/0001-70
# 77095       FI  26.470.647/0001-70
# 77096       FI  26.470.647/0001-70
# ...

# %%
#calcula pesos
total_pos=df.loc[df["CNPJ_FUNDO"]=="26.470.647/0001-70","VL_MERC_POS_FINAL"].sum()
total_pos
sub_df["PESO"]=sub_df["VL_MERC_POS_FINAL"]/total_pos
sub_df
# Out:
# C:\Users\Marcelo\AppData\Local\Temp\ipykernel_92780\3907989473.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["PESO"]=sub_df["VL_MERC_POS_FINAL"]/total_pos
#       TP_FUNDO          CNPJ_FUNDO  \
# 77083       FI  26.470.647/0001-70
# 77084       FI  26.470.647/0001-70
# 77085       FI  26.470.647/0001-70
# 77086       FI  26.470.647/0001-70
# 77087       FI  26.470.647/0001-70
# 77088       FI  26.470.647/0001-70
# 77089       FI  26.470.647/0001-70
# 77090       FI  26.470.647/0001-70
# 77091       FI  26.470.647/0001-70
# 77092       FI  26.470.647/0001-70
# 77093       FI  26.470.647/0001-70
# 77094       FI  26.470.647/0001-70
# 77095       FI  26.470.647/0001-70
# 77096       FI  26.470.647/0001-70
# ...
